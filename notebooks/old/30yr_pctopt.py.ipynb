# %%
from   datetime import datetime
import sys

import matplotlib.pyplot as plt

sys.path.append('..')
from models.pct_in_optimizer.optimizer import (
    PercentInOptimizer, plot_results)

# %%
RECURSION_LIMIT = 100
sys.setrecursionlimit(RECURSION_LIMIT)

# %%
FRIDAY = 4
weekday = datetime.now().weekday()
ITERS = 60 if weekday >= FRIDAY else 1
print('ITERS:', ITERS)
OUTPATH = '../data/pct_params'
years_of_data = 30
symbols = ['^W5000', '^IXIC']
tickers = {'^W5000': 'wilshire',
           '^IXIC': 'nasdaq'}
paths = {'^NYA': '../data/nya1965.csv',
         '^IXIC': '../data/nasdaq1965.csv',
         '^W5000': '../data/wilshire1990.csv'}
# Out:
# ITERS: 60

# %%
percent_in = {}

for symbol in symbols:
    ticker = tickers[symbol]
    path = paths[symbol]
    percent_in[ticker] = {'pct_in': [], 'multiplier': []}
    print(f'\n\n\n{"=" * 60}')
    print(ticker.upper())
    print('=' * 60)
    for n_params in [4, 3, 2]:
        print(f'\n\n{"-" * 50}')
        print(f'Beginning {n_params}-param model...')
        print('-' * 50)
        filename = f'{ticker}_3yr_{n_params}param.json'
        optim = PercentInOptimizer(n_params, years_of_data, symbol)
        optim.load_params(f'{OUTPATH}/{filename}')
        optim.get_data(df=path)
        specified = None
        best_data = optim.run_sim(ITERS)
        percent_in[ticker]['pct_in'].append(plot_results(best_data))
        mod_returns = (
            best_data.Total.tolist()[-1] / best_data.Total.tolist()[1])
        market_returns = (
            best_data.Value.tolist()[-1] / best_data.Value.tolist()[1])
        multiplier = mod_returns / market_returns
        percent_in[ticker]['multiplier'].append(multiplier)
        optim.save_params(f'{OUTPATH}/{filename}')
        plt.show()
# Out:
# ============================================================
# WILSHIRE
# ============================================================
#
#
# --------------------------------------------------
# Beginning 4-param model...
# --------------------------------------------------
# Using start date: 1992-04-15
# Successfully loaded params from ../data/pct_params/wilshire_3yr_4param.json
# {   'params': {   'amounts': [-0.99, 0.936912059195543, -0.99, -0.99],
#                   'qs': [   -0.21949182679147575,
#                             -0.15797307153881793,
#                             -0.99,
#                             -0.99]},
#     'sd': 0.628139143994939,
#     'window': 630}
#  1: Final value: $ 5682.23 (window = 630; sd = 0.628)
#  2: Final value: $13219.09 (window = 571; sd = 0.622)
# New best model!
# {   'amounts': [-0.99, 0.99, 0.99, -0.45414953138689707],
#     'qs': [-0.2897030034979077, 0.5365526656275003, -0.7922349197439109, -0.99]}
#  4: Final value: $44180.85 (window = 730; sd = 0.923)
# New best model!
# {   'amounts': [   0.5938629702357945,
#                    0.99,
#                    -0.06505949085248197,
#                    0.22306977083413337],
#     'qs': [0.7291794963592143, 0.99, -0.99, -0.99]}
# 60: Final value: $ 8922.95 (window = 411; sd = 0.589))
# % in now: 1.0
# Actions taken: 53
# Wrote params to ../data/pct_params/wilshire_3yr_4param.json
# --------------------------------------------------
# Beginning 3-param model...
# --------------------------------------------------
# Using start date: 1992-04-15
# Successfully loaded params from ../data/pct_params/wilshire_3yr_3param.json
# {   'params': {   'amounts': [-0.99, 0.99, 0.99],
#                   'qs': [-0.99, 0.5140615876326061, -0.5127820992386558]},
#     'sd': 0.11221289529686855,
#     'window': 20}
#  1: Final value: $43300.33 (window = 20; sd = 0.112)
#  2: Final value: $46930.24 (window = 20; sd = 0.111)
# New best model!
# {   'amounts': [-0.31569552892338326, 0.7007226203908935, 0.878965285308077],
#     'qs': [-0.9016382608806002, 0.4656817421476002, -0.380517984813192]}
# 60: Final value: $23703.49 (window = 263; sd = 0.094)
# % in now: 0.9608280963070931
# Actions taken: 1102
# Wrote params to ../data/pct_params/wilshire_3yr_3param.json
# --------------------------------------------------
# Beginning 2-param model...
# --------------------------------------------------
# Using start date: 1992-04-15
# Successfully loaded params from ../data/pct_params/wilshire_3yr_2param.json
# {   'params': {   'amounts': [0.5835734988618322, -0.7860484788964534],
#                   'qs': [-0.3845727569057431, 0.508583828644781]},
#     'sd': 0.11338089920189827,
#     'window': 563}
#  1: Final value: $17157.51 (window = 563; sd = 0.113)
#  2: Final value: $27865.19 (window = 608; sd = 0.112)
# New best model!
# {   'amounts': [0.8162855017008066, -0.3468872649942206],
#     'qs': [-0.24306317116162435, 0.7566972889515172]}
#  3: Final value: $39581.64 (window = 569; sd = 0.168)
# New best model!
# {   'amounts': [0.5917009934132886, -0.4845338351663692],
#     'qs': [-0.40745590221820804, 0.8759349275345801]}
#  8: Final value: $40412.11 (window = 503; sd = 0.243)
# New best model!
# {   'amounts': [0.11771602061743758, -0.010283450748533013],
#     'qs': [-0.40082643468890883, 0.6230999539160531]}
# 10: Final value: $42382.80 (window = 545; sd = 0.360)
# New best model!
# {   'amounts': [-0.002777608910181889, 0.09092067771376659],
#     'qs': [-0.3685338956741309, 0.6213859027582426]}
# 12: Final value: $43757.62 (window = 449; sd = 0.535)
# New best model!
# {   'amounts': [0.6746765541383338, -0.0011528737072441508],
#     'qs': [-0.08545811133660186, 0.8617906449978152]}
# 13: Final value: $44180.85 (window = 476; sd = 0.802)
# New best model!
# {   'amounts': [0.715748134029596, -0.2300339305981945],
#     'qs': [-0.0922401050957571, 0.9493747177662503]}
# 60: Final value: $44180.85 (window = 184; sd = 0.645)
# % in now: 1.0
# Actions taken: 27
# Wrote params to ../data/pct_params/wilshire_3yr_2param.json
# ============================================================
# NASDAQ
# ============================================================
#
#
# --------------------------------------------------
# Beginning 4-param model...
# --------------------------------------------------
# Using start date: 1992-04-15
# Successfully loaded params from ../data/pct_params/nasdaq_3yr_4param.json
# {   'params': {   'amounts': [0.99, 0.99, 0.99, -0.99],
#                   'qs': [   0.42767326694810814,
#                             -0.99,
#                             0.6694234657746163,
#                             -0.99]},
#     'sd': 0.5170031501179593,
#     'window': 20}
#  1: Final value: $ 9780.88 (window = 20; sd = 0.517)
# 13: Final value: $12665.92 (window = 20; sd = 0.458))
# New best model!
# {   'amounts': [   0.060801172645832624,
#                    0.0924439400931909,
#                    0.43398781128692676,
#                    -0.33367389641557654],
#     'qs': [-0.15653009623692044, 0.5864976586961149, 0.9544313439549739, 0.99]}
# 21: Final value: $13351.08 (window = 651; sd = 0.641)
# New best model!
# {   'amounts': [   -0.12846739554778175,
#                    0.15268115708558794,
#                    0.2919060220443396,
#                    0.99],
#     'qs': [-0.99, 0.99, -0.99, -0.99]}
# 23: Final value: $14550.91 (window = 561; sd = 0.951)
# New best model!
# {   'amounts': [-0.99, 0.7671035821730332, 0.99, 0.99],
#     'qs': [   -0.4652686829379892,
#               0.9345962026314869,
#               -0.36187713521387255,
#               -0.5844235007913072]}
# 25: Final value: $15245.55 (window = 141; sd = 1.014)
# New best model!
# {   'amounts': [-0.99, 0.99, -0.39458158158210566, 0.19312434283934998],
#     'qs': [-0.99, 0.6646678151435735, 0.088141731581308, -0.19777752771634505]}
# 60: Final value: $ 6525.22 (window = 257; sd = 0.728)
# % in now: 0.23486308945609544
# Actions taken: 297
# Wrote params to ../data/pct_params/nasdaq_3yr_4param.json
# --------------------------------------------------
# Beginning 3-param model...
# --------------------------------------------------
# Using start date: 1992-04-15
# Successfully loaded params from ../data/pct_params/nasdaq_3yr_3param.json
# {   'params': {   'amounts': [0.99, 0.99, -0.6429249267059606],
#                   'qs': [   -0.01345998836222588,
#                             0.2013135459204507,
#                             -0.43371664382145286]},
#     'sd': 0.19656315828215729,
#     'window': 73}
#  1: Final value: $ 2227.47 (window = 73; sd = 0.197)
#  2: Final value: $ 8424.80 (window = 198; sd = 0.195)
# New best model!
# {   'amounts': [0.99, 0.859129652751119, -0.8480745454700265],
#     'qs': [-0.3374842784210773, 0.4601702006361103, -0.42089167041795106]}
#  7: Final value: $13351.08 (window = 573; sd = 0.280)
# New best model!
# {   'amounts': [0.99, 0.16719663328674117, -0.99],
#     'qs': [-0.8257227490981566, 0.36029026044685003, -0.9851359420128648]}
# 60: Final value: $  859.36 (window = 197; sd = 0.249)
# % in now: 1.0
# Actions taken: 139
# Wrote params to ../data/pct_params/nasdaq_3yr_3param.json
# --------------------------------------------------
# Beginning 2-param model...
# --------------------------------------------------
# Using start date: 1992-04-15
# Successfully loaded params from ../data/pct_params/nasdaq_3yr_2param.json
# {   'params': {   'amounts': [-0.15199853157725746, 0.99],
#                   'qs': [0.4403442759576444, 0.010444724364551612]},
#     'sd': 0.8375367040995642,
#     'window': 151}
#  1: Final value: $  746.87 (window = 151; sd = 0.838)
#  2: Final value: $  851.49 (window = 694; sd = 0.829)
# New best model!
# {'amounts': [-0.99, 0.99], 'qs': [0.4102672072857359, 0.99]}
#  3: Final value: $ 2266.18 (window = 966; sd = 1.024)
# New best model!
# {'amounts': [-0.99, 0.99], 'qs': [-0.3089417621931379, 0.7284139041169155]}
#  4: Final value: $13351.08 (window = 620; sd = 1.024)
# New best model!
# {   'amounts': [-0.8121403113572594, 0.8586429014900087],
#     'qs': [0.953622505647139, -0.30755813169516344]}
# 26: Final value: $13638.00 (window = 49; sd = 0.829)))
# New best model!
# {'amounts': [0.99, -0.99], 'qs': [-0.99, 0.99]}
# 60: Final value: $  905.43 (window = 471; sd = 0.735))
# % in now: 0.998471388348781
# Actions taken: 14
# Wrote params to ../data/pct_params/nasdaq_3yr_2param.json

# %%
for idx, data in percent_in.items():
    for i, pct in enumerate(data['multiplier']):
        if pct <= 1:
            data['pct_in'][i] = 1
            data['multiplier'][i] = 0
for idx, data in percent_in.items():
    print(idx)
    for k, v in data.items():
        print(f'  {k:10s}:', end=' ')
        for amt in v:
            print(f'{amt:.4f}', end=' ')
        print()
    print()
# Out:
# wilshire
#   pct_in    : 1.0000 0.9608 1.0000
#   multiplier: 1.0000 1.0622 1.0000
#
# nasdaq
#   pct_in    : 0.2349 1.0000 0.9985
#   multiplier: 1.1419 0.0000 1.0215

# %%
# !say 30 year done
